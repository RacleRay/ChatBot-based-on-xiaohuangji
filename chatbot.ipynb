# %%
# %load_ext autoreload
# %autoreload 2

# %%
# mount方式有buffer限制
from google.colab import drive
drive.mount('/content/gdrive')

# %%
% cd /content/gdrive/My\ Drive/Colab\ Notebooks/chatbot_xiaohuangji
# Out:
# /content/gdrive/My Drive/Colab Notebooks/chatbot_xiaohuangji

# %%
# !ls -l
# Out:
# total 79545
# -rw------- 1 root root   136361 Jun 27 03:17 chatbot.ipynb
# -rw------- 1 root root 50140325 Jun 24 09:47 chatbot.pkl
# -rw------- 1 root root     8872 Jun 14 06:04 data_utils.py
# -rw------- 1 root root     6045 Jun 24 09:44 extract_file.py
# -rw------- 1 root root     2188 Jun 14 06:04 fake_data.py
# drwx------ 2 root root     4096 Jun 14 06:28 model
# drwx------ 2 root root     4096 Jun 24 13:46 model_anti
# drwx------ 2 root root     4096 Jun 15 11:56 model_anti-1
# drwx------ 2 root root     4096 Jun 24 13:46 model_anti-2
# drwx------ 2 root root     4096 Jun 25 12:04 model_anti_best
# -rw------- 1 root root      263 Jun 16 05:42 params.json
# drwx------ 2 root root     4096 Jun 14 06:23 __pycache__
# -rw------- 1 root root    42306 Jun 25 11:28 seq_2_seq.py
# -rw------- 1 root root     2583 Jun 14 06:04 threadedgenerator.py
# -rw------- 1 root root     6054 Jun 25 12:06 train_anti.py
# -rw------- 1 root root     3809 Jun 14 06:04 train.py
# ...

# %%
# !/opt/bin/nvidia-smi
# Out:
# Thu Jun 27 01:59:01 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 410.79       Driver Version: 410.79       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8    15W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %% [markdown]
# ### 文本数据处理

# %%
! python extract_file.py
# Out:
# extracting lines
# 1363692it [00:24, 56490.51it/s]
# 100% 454211/454211 [00:03<00:00, 132686.56it/s]
# 348204 348204
# 呵
# 是王若猫的
# --------------------
# 不
# 那是什么
# --------------------
# 怎么
# 我很难过，安慰我
# --------------------
# 开心点哈，一切都会好起
# 嗯会
# --------------------
# 我还喜欢她，怎么
# 我帮你告诉她？发短信还是打电话
# --------------------
# 短
# 嗯嗯。我也相
# --------------------
# 你知道谁
# 肯定不是我，是阮德
# --------------------
# 许兵是
# 吴院四班小帅
# --------------------
# 这么
# 三鹿奶粉也假，不一样的卖
# --------------------
# 许兵是傻
# 被你发现了
# --------------------
# 许兵是
# 是我善良可爱的主人的老公
# --------------------
# 许兵是
# 是穆森的老婆
# --------------------
# 许兵是
# 奇
# --------------------
# 许兵到底是
# 不要凶我～应该大概也许是叶祺吧
# --------------------
# 尼玛，许兵到底是
# 我。我不会告诉你我是小澜的！V
# --------------------
# 小黄鸭，你有女朋友
# 老娘是女的
# --------------------
# 那你有男朋友
# 没有呢，我只要主人一个人疼爱我嘛。
# --------------------
# 那你在
# 我无
# --------------------
# 你妈是
# 我妈妈是世界上最温柔的主人你
# --------------------
# 去你大爷
# 我去，滚你大爷的
# --------------------
# fit word_sequence
# dump
# done

# %% [markdown]
# ### 训练
# ---
#
#
# * train-anti：加入负样本
# * train：不加入负样本
#
# 超参数调整：params.json文件中调整

# %%
! python train_anti.py
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0626 13:23:12.801804 139909814429568 deprecation_wrapper.py:119] From train_anti.py:28: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0626 13:23:12.802157 139909814429568 deprecation_wrapper.py:119] From train_anti.py:38: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# W0626 13:23:12.806618 139909814429568 deprecation_wrapper.py:119] From train_anti.py:42: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# W0626 13:23:12.806808 139909814429568 deprecation_wrapper.py:119] From train_anti.py:44: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-06-26 13:23:12.822866: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# ...

# %%
! python train_anti.py
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0626 17:35:17.978398 140423413213056 deprecation_wrapper.py:119] From train_anti.py:28: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0626 17:35:17.978832 140423413213056 deprecation_wrapper.py:119] From train_anti.py:38: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# W0626 17:35:17.984968 140423413213056 deprecation_wrapper.py:119] From train_anti.py:42: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# W0626 17:35:17.985173 140423413213056 deprecation_wrapper.py:119] From train_anti.py:44: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-06-26 17:35:17.989983: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# ...

# %% [markdown]
# ### 测试

# %%
! python validation_anti.py
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0627 03:37:15.978938 140033433024384 deprecation_wrapper.py:119] From validation_anti.py:28: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0627 03:37:15.979385 140033433024384 deprecation_wrapper.py:119] From validation_anti.py:36: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# W0627 03:37:15.979715 140033433024384 deprecation.py:506] From /content/gdrive/My Drive/Colab Notebooks/chatbot_xiaohuangji/seq_2_seq.py:151: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# ...
